# %% [markdown]
# # Marks Sheet

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame(np.random.randint(20,32, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df2 = pd.DataFrame(np.random.randint(33,39, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df3 = pd.DataFrame(np.random.randint(40,49, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df4 = pd.DataFrame(np.random.randint(50,59, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df5 = pd.DataFrame(np.random.randint(60,69, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df6 = pd.DataFrame(np.random.randint(70,79, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])
df7 = pd.DataFrame(np.random.randint(80,100, size=(5000,5)),
                 columns=['s1','s2','s3','s4','s5'])

df = pd.concat([df1,df2,df3,df4,df5,df6,df7])



df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  22  26  27  20  25
# 1  25  25  28  26  21
# 2  24  31  25  30  24
# 3  29  28  21  28  21
# 4  25  20  26  28  28

# %%
df['obtained'] = df.s1 + df.s2 + df.s3 + df.s4 + df.s5
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained
# 0  22  26  27  20  25       120
# 1  25  25  28  26  21       125
# 2  24  31  25  30  24       134
# 3  29  28  21  28  21       127
# 4  25  20  26  28  28       127

# %%
df['percentage'] = df.obtained / 500 * 100
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage
# 0  22  26  27  20  25       120        24.0
# 1  25  25  28  26  21       125        25.0
# 2  24  31  25  30  24       134        26.8
# 3  29  28  21  28  21       127        25.4
# 4  25  20  26  28  28       127        25.4

# %% [markdown]
# # apply Symbolic AI, Classicial programming, tranditional programming, Rules Based programmin
# - Rules always define by programmer

# %% [markdown]
# - Rules + Input = Output

# %%
def grade(x):
    if x >= 80:
        return "A+"
    elif x >= 70:
        return "A"
    elif x >= 60:
        return "B"
    elif x >= 50:
        return "C"
    elif x >= 40:
        return "D"
    elif x >= 33:
        return "E"
    else:
        return "F"
    
df['Grade'] = df.percentage.apply(grade)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage Grade
# 0  22  26  27  20  25       120        24.0     F
# 1  25  25  28  26  21       125        25.0     F
# 2  24  31  25  30  24       134        26.8     F
# 3  29  28  21  28  21       127        25.4     F
# 4  25  20  26  28  28       127        25.4     F

# %%
df.Grade.value_counts()
# Out:
# B     5000
# A     5000
# D     5000
# F     5000
# A+    5000
# E     5000
# C     5000
# Name: Grade, dtype: int64

# %%
df.corr().plot(kind='bar')

# %%
dic = {
    'F':7,
    "E":6,
    "D":5,
    "C":4,
    "B":3,
    "A":2,
    "A+":1
}
df['Grade1'] = df.Grade.map(dic)
df.head()
# Out:
#    s1  s2  s3  s4  s5  obtained  percentage Grade  Grade1
# 0  22  26  27  20  25       120        24.0     F       7
# 1  25  25  28  26  21       125        25.0     F       7
# 2  24  31  25  30  24       134        26.8     F       7
# 3  29  28  21  28  21       127        25.4     F       7
# 4  25  20  26  28  28       127        25.4     F       7

# %%
df.corr().plot(kind='bar')

# %% [markdown]
# # Find Grades(Rules) with Deep Learning
# - input + Output = Rules

# %%
df1 = df[['s1', 's2', 's3', 's4', 's5', 'Grade']]
df1.head(2)
df1 = df1.sample(frac=1)
df1
# Out:
#       s1  s2  s3  s4  s5 Grade
# 1361  80  94  84  95  94    A+
# 2318  67  64  60  62  61     B
# 2011  68  67  67  68  67     B
# 4105  65  67  62  66  66     B
# 3820  53  57  53  55  57     C
# ...   ..  ..  ..  ..  ..   ...
# 2786  44  45  44  47  44     D
# 2182  67  64  67  63  67     B
# 1321  70  77  70  70  75     A
# 2387  31  30  29  30  31     F
# 780   62  68  60  63  64     B
#
# [35000 rows x 6 columns]

# %%
X = df1.loc[:, 's1':'s5']
X.head()
# Out:
#       s1  s2  s3  s4  s5
# 1361  80  94  84  95  94
# 2318  67  64  60  62  61
# 2011  68  67  67  68  67
# 4105  65  67  62  66  66
# 3820  53  57  53  55  57

# %%
Y = df1[['Grade']]
Y.head()
# Out:
#      Grade
# 1361    A+
# 2318     B
# 2011     B
# 4105     B
# 3820     C

# %% [markdown]
# # Vectorization to Y
# - one-hot-encoding

# %% [raw]
#     A B C
# A   1 0 0
# B   0 1 0
# C   0 0 1

# %%
Y = df1['Grade']
Y = pd.get_dummies(Y)
Y.head()
# Out:
#       A  A+  B  C  D  E  F
# 1361  0   1  0  0  0  0  0
# 2318  0   0  1  0  0  0  0
# 2011  0   0  1  0  0  0  0
# 4105  0   0  1  0  0  0  0
# 3820  0   0  0  1  0  0  0

# %%
Y.drop_duplicates()
# Out:
#       A  A+  B  C  D  E  F
# 1361  0   1  0  0  0  0  0
# 2318  0   0  1  0  0  0  0
# 3820  0   0  0  1  0  0  0
# 2499  0   0  0  0  0  1  0
# 3283  1   0  0  0  0  0  0
# 373   0   0  0  0  1  0  0
# 2101  0   0  0  0  0  0  1

# %% [raw]
#    s1 s2 s3 s4 s5     A   A+  B  C   D   E   F
# [[98,56,79,90,50]] = [.3, .1,.20,.1, .1, .1, .1]

# %% [markdown]
# ##### import some fundamentals lib

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam, SGD

# %% [markdown]
# Create your model network structure
# - first-layer (input_shape = X.no_of_columns)
# - last-layers (output=Y.unique_labels(unique classes))
#     - activation = according to your problems (4.6)
# - Dense(output, )

# %%
model = Sequential()
model.add(Dense(32, activation='relu', input_shape=(5,)))
model.add(Dense(16, activation='relu', input_shape=(5,)))
model.add(Dense(7, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                192
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 119
# =================================================================
# Total params: 839
# Trainable params: 839
# Non-trainable params: 0
# _________________________________________________________________

# %%
# select loss function based on your problems

model.compile(optimizer=SGD(lr=0.002),
             loss='categorical_crossentropy',
             metrics=['acc'])

# %%
model.fit(X, Y, epochs=30)
# Out:
# Epoch 1/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2991 - acc: 0.4996
# Epoch 2/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2707 - acc: 0.5175
# Epoch 3/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2535 - acc: 0.5355
# Epoch 4/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2286 - acc: 0.5520
# Epoch 5/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.2046 - acc: 0.5668
# Epoch 6/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.1864 - acc: 0.5747
# Epoch 7/30
# 1094/1094 [==============================] - 3s 2ms/step - loss: 1.1707 - acc: 0.5886
# Epoch 8/30
# 1094/1094 [==============================] - 3s 3ms/step - loss: 1.1484 - acc: 0.6017
# Epoch 9/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.1293 - acc: 0.6105
# Epoch 10/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.1145 - acc: 0.6110
# Epoch 11/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0896 - acc: 0.6209
# Epoch 12/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0705 - acc: 0.6267
# Epoch 13/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0556 - acc: 0.6311
# Epoch 14/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0402 - acc: 0.6356
# Epoch 15/30
# 1094/1094 [==============================] - 3s 2ms/step - loss: 1.0210 - acc: 0.6410
# Epoch 16/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 1.0067 - acc: 0.6427
# Epoch 17/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9904 - acc: 0.6471
# Epoch 18/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9760 - acc: 0.6504
# Epoch 19/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9564 - acc: 0.6638
# Epoch 20/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9410 - acc: 0.6646
# Epoch 21/30
# 1094/1094 [==============================] - 3s 2ms/step - loss: 0.9250 - acc: 0.6728
# Epoch 22/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.9113 - acc: 0.6813
# Epoch 23/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8970 - acc: 0.6858
# Epoch 24/30
# 1094/1094 [==============================] - 3s 2ms/step - loss: 0.8798 - acc: 0.6896
# Epoch 25/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8696 - acc: 0.6960
# Epoch 26/30
# 1094/1094 [==============================] - 2s 2ms/step - loss: 0.8533 - acc: 0.7047
# Epoch 27/30
# 1094/1094 [==============================] - 3s 2ms/step - loss: 0.8361 - acc: 0.7114
# Epoch 28/30
# 1094/1094 [==============================] - 3s 2ms/step - loss: 0.8294 - acc: 0.7164
# Epoch 29/30
# 1094/1094 [==============================] - 3s 2ms/step - loss: 0.8159 - acc: 0.7211
# Epoch 30/30
# 1094/1094 [==============================] - 3s 3ms/step - loss: 0.8014 - acc: 0.7284

# %%
df1 = pd.DataFrame(np.random.randint(20,100, size=(20,5)),
                  columns = ['s1','s2','s3','s4','s5'])

df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  50  47  75  26  22
# 1  40  73  88  74  26
# 2  54  63  47  65  96
# 3  26  55  24  66  99
# 4  28  74  92  32  39

# %%
Y.columns.take(np.argmax(model.predict([[90,98,95,97,95]]), axis=1))
# Out:
# Index(['A'], dtype='object')

# %%
df1['predict']=Y.columns.take(np.argmax(model.predict(df1.loc[:,'s1':'s5']), axis=1))
df1
# Out:
#     s1  s2  s3  s4  s5 predict
# 0   50  47  75  26  22       F
# 1   40  73  88  74  26       F
# 2   54  63  47  65  96       D
# 3   26  55  24  66  99       D
# 4   28  74  92  32  39       D
# 5   37  47  52  37  38       D
# 6   53  21  22  48  26       F
# 7   62  48  82  54  95       D
# 8   61  95  64  46  86       D
# 9   30  29  35  81  97       D
# 10  37  38  75  60  53       D
# 11  91  98  47  89  63       D
# 12  73  37  68  88  39       F
# 13  47  85  30  21  58       D
# 14  53  74  52  94  75       D
# 15  52  46  65  72  54       D
# 16  28  67  25  96  43       F
# 17  36  48  77  93  62       D
# 18  32  93  44  25  80       D
# 19  43  30  93  22  66       F

# %% [markdown]
# # Computer Vision problem
# - load image from directory
# - apply Auto labels based on your folder names

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_data_gen = ImageDataGenerator(rescale=1.0/255)

# %%
train_data = train_data_gen.flow_from_directory(
    "./train",
    target_size=(150,150),
    batch_size=20,
    class_mode='binary'
)
# Out:
# Found 6 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam, SGD

# %%
150*150*3
# Out:
# 67500

# %%
model1 = Sequential()
model1.add(Flatten())
model1.add(Dense(5000, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))

# %%
model1.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['acc'])

# %%
#Train Model1
hist = model1.fit(train_data, epochs=15)
# Out:
# Epoch 1/15
# 1/1 [==============================] - 0s 34ms/step - loss: 0.7574 - acc: 0.5000
# Epoch 2/15
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6256 - acc: 0.8333
# Epoch 3/15
# 1/1 [==============================] - 0s 4ms/step - loss: 157.6549 - acc: 0.5000
# Epoch 4/15
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2378e-38 - acc: 1.0000
# Epoch 5/15
# 1/1 [==============================] - 0s 1ms/step - loss: 42.9724 - acc: 0.6667
# Epoch 6/15
# 1/1 [==============================] - 0s 2ms/step - loss: 13.5967 - acc: 0.8333
# Epoch 7/15
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - acc: 1.0000
# Epoch 8/15
# 1/1 [==============================] - 0s 710us/step - loss: 0.0000e+00 - acc: 1.0000
# Epoch 9/15
# 1/1 [==============================] - 0s 2ms/step - loss: 9.8488e-20 - acc: 1.0000
# Epoch 10/15
# 1/1 [==============================] - 0s 732us/step - loss: 18.4087 - acc: 0.6667
# Epoch 11/15
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - acc: 1.0000
# Epoch 12/15
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0000e+00 - acc: 1.0000
# Epoch 13/15
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - acc: 1.0000
# Epoch 14/15
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - acc: 1.0000
# Epoch 15/15
# 1/1 [==============================] - 0s 994us/step - loss: 8.2594e-06 - acc: 1.0000

# %%
# Test Data

# %%
test_data = train_data_gen.flow_from_directory(
    "./test",
    target_size=(150,150),
    batch_size=20,
    class_mode='binary'
)
# Out:
# Found 6 images belonging to 2 classes.

# %%
Y = model1.predict(test_data)
Y
# Out:
# array([[1.000000e+00],
#        [1.000000e+00],
#        [0.000000e+00],
#        [1.000000e+00],
#        [1.000000e+00],
#        [4.155443e-12]], dtype=float32)

# %%
np.where(Y>0, "Dog","Cat")
# Out:
# array([['Dog'],
#        ['Dog'],
#        ['Cat'],
#        ['Dog'],
#        ['Dog'],
#        ['Dog']], dtype='<U3')

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
img = image.load_img("./train/dog/2.jpg", target_size=(150,150))
x=image.img_to_array(img) / 255
x = x.reshape(1,-1)
model1.predict(x)
# Out:
# array([[1.]], dtype=float32)
